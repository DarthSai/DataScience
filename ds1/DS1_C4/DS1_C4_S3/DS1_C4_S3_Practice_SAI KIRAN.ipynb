# %%
import numpy as np
import pandas as pd
import os
os.getcwd()
# Out:
# 'D:\\darthsai'

# %%
bank=pd.read_csv('DS1_C4_S3_Loan_Data_Practice.csv')
bank
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#task 1
bank[(bank['Gender']=='Male')&(bank['Education']=='Graduate')&(bank['Loan_Status']=='Y')]
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 2    LP001005   Male     Yes          0  Graduate           Yes
# 4    LP001008   Male      No          0  Graduate            No
# 5    LP001011   Male     Yes          2  Graduate           Yes
# 8    LP001018   Male     Yes          2  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 606  LP002961   Male     Yes          1  Graduate            No
# 608  LP002974   Male     Yes          0  Graduate            No
# 610  LP002979   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
# 612  LP002984   Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
#task 2
bank[(bank['Gender']=='Female')&(bank['Self_Employed']=='Yes')&(bank['ApplicantIncome']>4000)]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
# 353  LP002142  Female     Yes          0      Graduate           Yes
# 370  LP002194  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 430  LP002377  Female      No          1      Graduate           Yes
# 439  LP002407  Female     Yes          0  Not Graduate           Yes
# 463  LP002489  Female      No          1  Not Graduate           Yes
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 534  LP002731  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
# ...

# %%
#task 3
bank[(bank['Dependents']=='3+')&(bank['Property_Area']=='Rural')&(bank['Loan_Status']=='Y')]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 126  LP001448    Male     Yes         3+      Graduate            No
# 213  LP001715    Male     Yes         3+  Not Graduate           Yes
# 255  LP001846  Female      No         3+      Graduate            No
# 324  LP002065    Male     Yes         3+      Graduate            No
# 352  LP002141    Male     Yes         3+      Graduate            No
# 376  LP002219    Male     Yes         3+      Graduate            No
# 390  LP002255    Male      No         3+      Graduate            No
# 391  LP002262    Male     Yes         3+      Graduate            No
# 481  LP002536    Male     Yes         3+  Not Graduate            No
# 515  LP002659    Male     Yes         3+      Graduate            No
# 522  LP002692    Male     Yes         3+      Graduate           Yes
# 539  LP002740    Male     Yes         3+      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
#
# ...

# %%
#task 4
loanmorethan290=bank[bank['LoanAmount']>=290]
avgincloanmorethan290k=loanmorethan290['ApplicantIncome'].mean()
print('The average income of applicant where the loan amount was more than or equal to 290,000 is',avgincloanmorethan290k)
# Out:
# The average income of applicant where the loan amount was more than or equal to 290,000 is 17736.878787878788

# %%
#task 5
unmarriedandselfemployed=bank[(bank['Married']=='No')&(bank['Self_Employed']=='Yes')&(bank['Loan_Status']=='N')]
len(unmarriedandselfemployed['Gender']=='Male')
print('There are',len(unmarriedandselfemployed[unmarriedandselfemployed['Gender']=='Male']),'males and',len(unmarriedandselfemployed[unmarriedandselfemployed['Gender']=='Female']),'females who are unmarried and self-employed and whose loan got rejected')
unmarriedandselfemployed
# Out:
# There are 9 males and 5 females who are unmarried and self-employed and whose loan got rejected
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 32   LP001097    Male      No          1      Graduate           Yes
# 95   LP001326    Male      No          0      Graduate           Yes
# 107  LP001370    Male      No          0  Not Graduate           Yes
# 199  LP001673    Male      No          0      Graduate           Yes
# 245  LP001813    Male      No          0      Graduate           Yes
# 254  LP001844    Male      No          0      Graduate           Yes
# 280  LP001910    Male      No          1  Not Graduate           Yes
# 286  LP001925  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 410  LP002318  Female      No          1  Not Graduate           Yes
# 438  LP002403    Male      No          0      Graduate           Yes
# ...

# %%
#task 6
urban=bank[bank['Property_Area']=='Urban']
print(urban[['ApplicantIncome','Property_Area']])
semiurban=bank[bank['Property_Area']=='Semiurban']
print(semiurban[['ApplicantIncome','Property_Area']])
rural=bank[bank['Property_Area']=='Rural']
print(rural[['ApplicantIncome','Property_Area']])
# Out:
#      ApplicantIncome Property_Area
# 0               5849         Urban
# 2               3000         Urban
# 3               2583         Urban
# 4               6000         Urban
# 5               5417         Urban
# ..               ...           ...
# 600              416         Urban
# 602             5703         Urban
# 605             2400         Urban
# 611             8072         Urban
# 612             7583         Urban
#
# [202 rows x 2 columns]
#      ApplicantIncome Property_Area
# 7               3036     Semiurban
# 9              12841     Semiurban
# 22              2600     Semiurban
# 24              3717     Semiurban
# 25              9560     Semiurban
# ..               ...           ...
# 592             9357     Semiurban
# 597             2987     Semiurban
# 604            12000     Semiurban
# 606             3400     Semiurban
# 613             4583     Semiurban
#
# [233 rows x 2 columns]
#      ApplicantIncome Property_Area
# ...

# %%
#task 7
bank[(bank['CoapplicantIncome']<bank['CoapplicantIncome'].mean())&(bank['Loan_Status']=='Y')]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 4    LP001008    Male      No          0      Graduate            No
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#task 8
len(bank[(bank['Education']=='Graduate')&(bank['ApplicantIncome'].between(10256,150000))])
print('There are',len(bank[(bank['Education']=='Graduate')&(bank['ApplicantIncome'].between(10256,150000))]),'customers who are graduates and whose income lies between $10,256 and $150,000')
# Out:
# There are 48 customers who are graduates and whose income lies between $10,256 and $150,000
