# %%
import numpy as np
import pandas as pd

# %%
bank=pd.read_csv('DS1_C4_S3_Loan_Data_Practice.csv')
T0=bank
bank
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#task 1
t1=bank[(bank['ApplicantIncome']<6000)&(bank['LoanAmount']>200)&(bank['Loan_Status']=='Y')]
print('There are',len(t1[t1['Gender']=='Male']),'males and',len(t1[t1['Gender']=='Female']),'females whose income is less than $6000 and loan amount is more than $200,000 whose loans are approved')
T1=t1[['Loan_ID','Gender']]
T1
# Out:
# There are 11 males and 1 females whose income is less than $6000 and loan amount is more than $200,000 whose loans are approved
#       Loan_ID  Gender
# 5    LP001011    Male
# 21   LP001046    Male
# 159  LP001552    Male
# 253  LP001843    Male
# 255  LP001846  Female
# 276  LP001903    Male
# 361  LP002170    Male
# 381  LP002229    Male
# 502  LP002615    Male
# 505  LP002622    Male
# 530  LP002717    Male
# 562  LP002820    Male

# %%
#task 2
surb=len(bank[bank['Property_Area']=='Semiurban'])
urb=len(bank[bank['Property_Area']=='Urban'])
print('There are',surb,'customers who have property in semi-urban areas and',urb,'customers who have property in urban areas. The percentage of customers with property in semiurban areas is',round((surb-urb)/urb*100,2),'% higher than those who have property in urban areas.' )
T2_1=bank[bank['Property_Area']=='Semiurban']
T2_2=bank[bank['Property_Area']=='Urban']
# Out:
# There are 233 customers who have property in semi-urban areas and 202 customers who have property in urban areas. The percentage of customers with property in semiurban areas is 15.35 % higher than those who have property in urban areas.

# %%
#task 3
bankincome=bank[(bank['Loan_Status']=='Y')].sort_values('ApplicantIncome',ascending=False)
T3=bankincome.iloc[:5]
T3
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 333  LP002101   Male     Yes          0  Graduate            No
# 171  LP001585   Male     Yes         3+  Graduate            No
# 155  LP001536   Male     Yes         3+  Graduate            No
# 185  LP001640   Male     Yes          0  Graduate           Yes
# 443  LP002422   Male      No          1  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 333            63337                0.0         490               180
# 171            51763                0.0         700               300
# 155            39999                0.0         600               180
# 185            39147             4750.0         120               360
# 443            37719                0.0         152               360
#
#      Credit_History Property_Area Loan_Status
# 333               1         Urban           Y
# 171               1         Urban           Y
# ...

# %%
#task 4
fem2dep=bank[(bank['Gender']=='Female')&(bank['Dependents']=='2')]
T4=fem2dep[['ApplicantIncome','LoanAmount']]
T4
# Out:
#      ApplicantIncome  LoanAmount
# 29              3750         120
# 82              1378         167
# 146            14866          70
# 219             4283         127
# 251             3427         138
# 293             5417         143
# 468              210          98
# 516             2031         113

# %%
#task 5
bank.loc[((bank['Gender']=='Female')&(bank['LoanAmount']>200)),'Loan_Amount_Term']=180
T5=bank[(bank['Gender']=='Female')&(bank['LoanAmount']>200)]['Loan_Amount_Term']
T5
# Out:
# 54     180
# 119    180
# 148    180
# 210    180
# 233    180
# 255    180
# 493    180
# 561    180
# 600    180
# 604    180
# Name: Loan_Amount_Term, dtype: int64

# %%
#task 6
bank=bank.rename(columns={'Loan_Amount_Term':'LoanAmountTerm'})
bank.loc[12,'LoanAmountTerm']=60
bank.loc[36,'LoanAmountTerm']=60
T6=bank.loc[[12,36]]
T6
# Out:
#      Loan_ID Gender Married Dependents Education Self_Employed  \
# 12  LP001028   Male     Yes          2  Graduate            No
# 36  LP001109   Male     Yes          0  Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  LoanAmountTerm  \
# 12             3073             8106.0         200              60
# 36             1828             1330.0         100              60
#
#     Credit_History Property_Area Loan_Status
# 12               1         Urban           Y
# 36               0         Urban           N

# %%
#task 7
creditcard=bank[(bank['Education']=='Graduate')&(bank['Self_Employed']=='Yes')&(bank['ApplicantIncome']>10000)]
creditcard['Credit_Limit']=creditcard['ApplicantIncome']*2
T7=creditcard
T7
# Out:
# C:\Users\saiki\AppData\Local\Temp\ipykernel_13144\3078390.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   creditcard['Credit_Limit']=creditcard['ApplicantIncome']*2
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 54   LP001186  Female     Yes          1  Graduate           Yes
# 128  LP001451    Male     Yes          1  Graduate           Yes
# 130  LP001469    Male      No          0  Graduate           Yes
# 185  LP001640    Male     Yes          0  Graduate           Yes
# 199  LP001673    Male      No          0  Graduate           Yes
# 254  LP001844    Male      No          0  Graduate           Yes
# 370  LP002194  Female      No          0  Graduate           Yes
# ...

# %%
#task 8
bankbackup=bank.copy()
kickout=bank[(bank['Dependents']=='3+')&(bank['Credit_History']==0)&(bank['Education']=='Not Graduate')]
ki=kickout.index
kickoutcopy=kickout.copy()
print(kickoutcopy)
bank.drop(ki,inplace=True)

T8_1=kickoutcopy
T8_2=bank

bank
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 73   LP001250    Male     Yes         3+  Not Graduate            No
# 338  LP002113  Female      No         3+  Not Graduate            No
# 466  LP002500    Male     Yes         3+  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  LoanAmountTerm  \
# 73              4755                0.0          95             342
# 338             1830                0.0         146             360
# 466             2947             1664.0          70             180
#
#      Credit_History Property_Area Loan_Status
# 73                0     Semiurban           N
# 338               0         Urban           N
# 466               0         Urban           N
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# ...

# %%
#task 9
grad=bank[bank['Education']=='Graduate']

notgrad=bank[bank['Education']=='Not Graduate']
print(grad['ApplicantIncome'],notgrad['ApplicantIncome'],end='    ')
T9_1=grad
T9_2=notgrad
# Out:
# 0      5849
# 1      4583
# 2      3000
# 4      6000
# 5      5417
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 480, dtype: int64 3      2583
# 6      2333
# 16     3596
# 18     4887
# 20     7660
#        ...
# 595    3833
# 596    6383
# 601    2894
# 605    2400
# 607    3987
# Name: ApplicantIncome, Length: 131, dtype: int64

# %%
#task 10
import xlsxwriter
with pd.ExcelWriter('Bank Challenge2.xlsx',engine='xlsxwriter') as wr:
    T0.to_excel(wr,sheet_name='task0')
    T1.to_excel(wr,sheet_name='task1')
    T2_1.to_excel(wr,sheet_name='task2.1')
    T2_2.to_excel(wr,sheet_name='task2.2')
    T3.to_excel(wr,sheet_name='task3')
    T4.to_excel(wr,sheet_name='task4')
    T5.to_excel(wr,sheet_name='task5')
    T6.to_excel(wr,sheet_name='task6')
    T7.to_excel(wr,sheet_name='task7')
    T8_1.to_excel(wr,sheet_name='task8.1')
    T8_2.to_excel(wr,sheet_name='task8.2')
    T9_1.to_excel(wr,sheet_name='task9.1')
    T9_2.to_excel(wr,sheet_name='task9.2')
