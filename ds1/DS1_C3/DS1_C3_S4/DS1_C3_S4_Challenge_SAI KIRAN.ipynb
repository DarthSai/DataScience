# %%
# using if else statemnts
print("please enter alpabet of option as answer, for example- c")
q1=input("what is the capital of Hungary ?  a.Brussels   b.Budapest   c.Birmingham   d.Copenhagen")
prize=0
if q1=='b':
    prize1=prize+1
    print("Correct!")
else:
    print("Incorrect!")
    prize1=prize
q2=input("In which country is the Vatican city state present in ?  a.Venice   b.Belgium    c.Italy    d.France")
if q2=='c':
    prize2=prize1+1
    print("Correct!")
else:
    print("Incorrect!")
    prize2=prize1
q3=input("Which of these is not a VTOL aircraft ?  a.Boeing F-35B  b.Bell V-22 Osprey  c.Su-35   d.Harrier ")
if q3=='c':
    prize3=prize2+1
    print("Correct!")
else:
    print("Incorrect!")
    prize3=prize2
q4=input("What's the 2nd most sucessful f1 team by constructor titles ?  a.Williams   b.Ferrari   c.Mercedes   d.McLaren")
if q4=='a':
    prize4=prize3+1
    print("Correct!")
else:
    print("Incorrect!")
    prize4=prize3
q5=input("Which of these countries was not neutral in WW2 ?  a.Spain  b.Denmark  c.Portugal   d.Belgium ")
if q5=='d':
    prize5=prize4+1
    print("Correct!")
else:
    print("Incorrect!")
    prize5=prize4
q6=input("What is the fastest naturally aspirated car ?  a.McLaren F-1  b.Bugatti Chiron  c.Hennessey Venom F-5  d.Thrust SSC")
if q6=='a':
    prize6=prize5+1
    print("Correct!")
else:
    print("Incorrect!")
    prize6=prize5
q7=input("What's the fastest bird ?  a.Kingfisher  b.Peregrine Falcon  c.American Bald Eagle   d. Common Swift ")
if q7=='b':
    prize7=prize6+1
    print("Correct!")
else:
    print("Incorrect!")
    prize7=prize6
q8=input("Which space probe has reached the furthest from earth ?  a.Voyager 1   b.Voyager-2    c.Pioneer-10    d.Pioneer-11")
if q8=='a':
    prize8=prize7+1
    print("Correct!")
else:
    print("Incorrect!")
    prize8=prize7
q9=input("Who was the ancient greek god of sun ?  a.Artemis  b.Zeus  c.Hades   d.Apollo ")
if q9=='d':
    prize9=prize8+1
    print("Correct!")
else:
    print("Incorrect!")
    prize9=prize8
q10=input("What is the hottest planet in our solar system ?  a.Mercury  b.Venus  c.Earth   d.Mars ")
if q10=='b':
    prize10=prize9+1
    print("Correct!")
else:
    print("Incorrect!")
    prize10=prize9
print("You got",prize10,"questions correct")
# Out:
# please enter alpabet of option as answer, for example- c
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 # task 1
#       2 print("please enter alpabet of option as answer, for example- c")
# ----> 3 q1=input("what is the capital of Hungary ?  a.Brussels   b.Budapest   c.Birmingham   d.Copenhagen")
#       4 prize=0
#       5 if q1=='b':
#
# File C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# ...

# %%
#using list and tuple along with if else statements
import random
questionswithkey=[
          ("what is the capital of Hungary ?  a.Brussels   b.Budapest   c.Birmingham   d.Copenhagen","b"),
          ("In which country is the Vatican city state present in ?  a.Venice   b.Belgium    c.Italy    d.France","c"),
          ("Which of these is not a VTOL aircraft ?  a.Boeing F-35B  b.Bell V-22 Osprey  c.Su-35   d.Harrier","c"),
          ("What is the 2nd most sucessful f1 team by constructor titles ?  a.Williams   b.Ferrari   c.Mercedes   d.McLaren","a"),
          ("Which of these countries was not neutral in WW2 ?  a.Spain  b.Denmark  c.Portugal   d.Belgium","d"),
          ("What is the fastest naturally aspirated car ?  a.McLaren F-1  b.Bugatti Chiron  c.Hennessey Venom F-5  d.Thrust SSC","a"),
          ("What is the fastest bird ?  a.Kingfisher  b.Peregrine Falcon  c.American Bald Eagle   d. Common Swift","b"),
          ("Which space probe has reached the furthest from earth ?  a.Voyager 1   b.Voyager-2    c.Pioneer-10    d.Pioneer-11","a"),
          ("Who was the ancient greek god of sun ?  a.Artemis  b.Zeus  c.Hades   d.Apollo","d"),
          ("What is the hottest planet in our solar system ?  a.Mercury  b.Venus  c.Earth   d.Mars","b")
          ]
c=0
for q,a in questionswithkey:
        print(q)
        ans=input("enter you asnwer as a,b,c or d: ")
        if ans==a:
            c=c+1
            print("Correct answer!")
        else:
            print("Wrong answer")
            c=c
print("you got",c,"answers correct")
# Out:
# what is the capital of Hungary ?  a.Brussels   b.Budapest   c.Birmingham   d.Copenhagen
# enter you asnwer as a,b,c or d: a
# Wrong answer
# In which country is the Vatican city state present in ?  a.Venice   b.Belgium    c.Italy    d.France
# enter you asnwer as a,b,c or d: a
# Wrong answer
# Which of these is not a VTOL aircraft ?  a.Boeing F-35B  b.Bell V-22 Osprey  c.Su-35   d.Harrier
# enter you asnwer as a,b,c or d: a
# Wrong answer
# What is the 2nd most sucessful f1 team by constructor titles ?  a.Williams   b.Ferrari   c.Mercedes   d.McLaren
# enter you asnwer as a,b,c or d: a
# Correct answer!
# Which of these countries was not neutral in WW2 ?  a.Spain  b.Denmark  c.Portugal   d.Belgium
# enter you asnwer as a,b,c or d: a
# Wrong answer
# What is the fastest naturally aspirated car ?  a.McLaren F-1  b.Bugatti Chiron  c.Hennessey Venom F-5  d.Thrust SSC
# enter you asnwer as a,b,c or d: a
# Correct answer!
# ...

# %%
# Out:
# what is the capital of Hungary ?  a.Brussels   b.Budapest   c.Birmingham   d.Copenhagen
# enter you asnwer as a,b,c or d: a
# Wrong answer
# In which country is the Vatican city state present in ?  a.Venice   b.Belgium    c.Italy    d.France
# enter you asnwer as a,b,c or d: s
# Wrong answer
# Which of these is not a VTOL aircraft ?  a.Boeing F-35B  b.Bell V-22 Osprey  c.Su-35   d.Harrier
# enter you asnwer as a,b,c or d: a
# Wrong answer
# What is the 2nd most sucessful f1 team by constructor titles ?  a.Williams   b.Ferrari   c.Mercedes   d.McLaren
# enter you asnwer as a,b,c or d: a
# Correct answer!
# Which of these countries was not neutral in WW2 ?  a.Spain  b.Denmark  c.Portugal   d.Belgium
# enter you asnwer as a,b,c or d: a
# Wrong answer
# What is the fastest naturally aspirated car ?  a.McLaren F-1  b.Bugatti Chiron  c.Hennessey Venom F-5  d.Thrust SSC
# enter you asnwer as a,b,c or d: a
# Correct answer!
# ...
