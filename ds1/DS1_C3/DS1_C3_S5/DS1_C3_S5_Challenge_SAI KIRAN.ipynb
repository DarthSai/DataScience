# %%
def converter():
    l=[
        'To convert a value from Radians to Degrees                  type 1 and press enter',
        'To convert a value from Degrees to Radians                  type 2 and press enter',
        'To calculate factorial of a number                          type 3 and press enter',
        'To calculate sqaure root of a number                        type 4 and press enter',
        'To convert a value from Megabyte to Nibble                  type 5 and press enter',
        'To convert a value from Fraction to Decimal                 type 6 and press enter',
        'To convert a value from Kilometre/hour to Metre/sec         type 7 and press enter',
        'To convert a value from Metre/sec to Kilometre/hour         type 8 and press enter',
        'To convert a value from Integer to Float                    type 9 and press enter',
        'To convert a value from Float to Integer                    type 10 and press enter',
        'To convert a value from Decimal to Octal                    type 11 and press enter',
        'To convert a value from Octal to Decimal                    type 12 and press enter',
        'To convert a value from Decimal to Hexadecimal              type 13 and press enter',
        'To convert a value from Hexadecimal to Decimal              type 14 and press enter',
        'To convert a value from Decimal to Binary                   type 15 and press enter',
        'To convert a value from Binary to Decimal                   type 16 and press enter',
        'To convert a value from Character to ASCII                  type 17 and press enter',
        'To convert a value from ASCII to Character                  type 18 and press enter',
        'To convert a value from Celcius to Fahrenheit               type 19 and press enter',
        'To convert a value from Fahrenheit to Celcius               type 20 and press enter',
      ]
    
    for i in l:
        print(i)
        
    choice=int(input('Enter a number and press enter: '))
    if choice==1:
        angle=int(input("enter the angle in radians: "))
        a=angle*180/3.1415
        print(angle,"radians is",a,"degrees")
    elif choice==2:
        angle=int(input("enter the angle in degrees: "))
        a=angle*3.1415/180
        print(angle,"degrees is",a,"radians")
    elif choice==3:
        n=int(input("enter a number: "))
        def factorial(n):
            i=1
            f=1
            while i<=n:
                f=i*f
                i=i+1
            return f
        z=factorial(n)
        print("the factorial of",n,"is",z)
    elif choice==4:
        n=int(input("enter a number: "))
        r=n**0.5
        print("the sqaure root of",n,"is",r)
    elif choice==5:
        mb=int(input("enter the size in megabytes: "))
        n=mb*2000000
        print(mb,"megabytes is",n,"nibbles")
    elif choice==6:
        n=int(input("enter the numerator of the fraction: "))
        d=int(input("enter the denominator of the fraction: "))
        dec=n/d
        print(n,'/',d,"=",dec)
    elif choice==7:
        kmh=int(input("enter the speed in Kilometre/hour: "))
        ms=kmh*5/18
        print(kmh,"Kilometres/hour is",ms,"Metres/second")
    elif choice==8:
        ms=int(input("enter the angle in degrees: "))
        kmh=ms*18/5
        print(ms,"Metres/second is",kmh,"Kilometres/hour")
    elif choice==9:
        intiger=int(input("enter a number: "))
        fl=float(intiger)
        print(intiger,"in intiger is",fl,"in float")
    elif choice==10:
        fl=float(input("enter a number: "))
        intiger=int(fl)
        print(fl,"in float is",intiger,"in intiger")
    elif choice==11:
        dec=int(input("enter the value in decimals: "))
        octal=oct(dec)
        print(dec,"in decimal is",octal,"in octal")
    elif choice==12:
        octal=input("Enter a value in octal format: ")
        dec=int(octal,8)
        print(octal,"in octal is",dec,"in decimal")
    elif choice==13:
        dec=int(input("enter the value in decimals: "))
        hexa=hex(dec)
        print(dec,"in decimal is",hexa,"in hexadecimal")
    elif choice==14:
        hexa=input("enter the value in Hexadecimal: ")
        dec=int(hexa,16)
        print(hexa,"in hexadecimal is",dec,"in decimal")
    elif choice==15:
        dec=int(input("enter the value in decimals: "))
        binary=bin(dec)
        print(dec,"in decimal is",binary,"in binary")        
    elif choice==16:
        binary=input("enter the value in binary: ")
        dec=int(binary,2)
        print(binary,"in binary is",dec,"in decimal")
    elif choice==17:
        ch=input("enter an ASCII code: ")
        asci=ord(ch)
        print("The ASCII code of",ch,"is",asci)
    elif choice==18:
        asci=int(input("enter a character: "))
        ch=chr(asci)
        print("The character whose ASCII code is",asci,"is",ch)
    elif choice==19:
        c=int(input("enter the temperature in degrees celcius: "))
        f=(c*9/5)+32
        print(c,"degrees celcius is",f," degrees fahrenheit")
    elif choice==20:
        f=int(input("enter the temperature in degrees fahrenheit: "))
        c=(f-32)*5/9
        print(f,"degrees fahrenheit is",c,"degrees celcius")
    else:
        print("Please check if your input is a number between 1 and 20,both inclusive")
converter()
# Out:
# To convert a value from Radians to Degrees                  type 1 and press enter
# To convert a value from Degrees to Radians                  type 2 and press enter
# To calculate factorial of a number                          type 3 and press enter
# To calculate sqaure root of a number                        type 4 and press enter
# To convert a value from Megabyte to Nibble                  type 5 and press enter
# To convert a value from Fraction to Decimal                 type 6 and press enter
# To convert a value from Kilometre/hour to Metre/sec         type 7 and press enter
# To convert a value from Metre/sec to Kilometre/hour         type 8 and press enter
# To convert a value from Integer to Float                    type 9 and press enter
# To convert a value from Float to Integer                    type 10 and press enter
# To convert a value from Decimal to Octal                    type 11 and press enter
# ...
