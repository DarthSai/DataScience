# %% [markdown]
# # 3 Levels of Analysis
#
# * Level 0 : Getting Started
# * Level 1 : Univariate Analysis
# * Level 2 : Bi-variate Analysis
# * Lever 3 : Multivariate Analysis and asking questions from the data

# %% [markdown]
# ## Level 0 Tasks (Getting Started)
#
# 1.Visually inspect the first few and last few rows of the data \
# 2.Check the shape of the data frame \
# 3.Check the count of null values in each column \
# 4.Inspect all the column names and cross check with the data dictionary \
# 5.Check the information of the data frame using the info() function

# %% [markdown]
# # Importing the necessary libraries

# %%
import matplotlib.pyplot as plt             # to visualize
from tabulate import tabulate               # to print the table
import matplotlib as mat                    # to visualize 
import seaborn as sns                       # to visualize
import pandas as pd                         # for data reading
import numpy as np                          # for numerical computation

# %%
# Check for the version of the libraries 
print("Pandas version: ",pd.__version__)
print("Seaborn version: ",sns.__version__)
print("Matplotlib version: ",mat.__version__)
# Out:
# Pandas version:  1.4.2
# Seaborn version:  0.11.2
# Matplotlib version:  3.5.1

# %% [markdown]
# # Reading the file

# %%
# Ensure that data to be read is in the same working directory. 
df = pd.read_csv("data2.csv") # read_csv: inbuilt function of pandas to read files

# %% [markdown]
# # Level 0 analysis

# %% [markdown]
# # Reading the top 5 rows

# %%
df.head() # head prints the top 5 rows
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 0  41.0       Yes      Travel_Rarely                   Sales
# 1  49.0        No  Travel_Frequently  Research & Development
# 2  37.0       Yes      Travel_Rarely  Research & Development
# 3  33.0        No  Travel_Frequently  Research & Development
# 4  27.0        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# 0                 1  Life Sciences               1                        2
# 1                 8  Life Sciences               2                        3
# 2                 2          Other               4                        4
# 3                 3  Life Sciences               5                        4
# 4                 2        Medical               7                        1
#
#    Gender  HourlyRate  ...  OverTime PerformanceRating  \
# 0  Female          94  ...       Yes                 3
# ...

# %% [markdown]
# # Reading the bottom 5 rows

# %%
df.tail() # tail returns the bottom 5 rows
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 1465  36.0        No                NaN  Research & Development
# 1466  39.0        No      Travel_Rarely  Research & Development
# 1467  27.0        No      Travel_Rarely  Research & Development
# 1468  49.0        No  Travel_Frequently                   Sales
# 1469  34.0        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome EducationField  EmployeeNumber  \
# 1465                23        Medical            2061
# 1466                 6        Medical            2062
# 1467                 4  Life Sciences            2064
# 1468                 2        Medical            2065
# 1469                 8        Medical            2068
#
#       EnvironmentSatisfaction Gender  HourlyRate  ...  OverTime  \
# 1465                        3   Male          41  ...        No
# 1466                        4   Male          42  ...        No
# ...

# %% [markdown]
# #  Number of rows and columns

# %%
print(df.shape) #returns a tuple of number of rows and columns
# Out:
# (1470, 27)

# %% [markdown]
# # Names of all the columns

# %%
print(df.columns) # returns array of columns in dataset
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PerformanceRating', 'RelationshipSatisfaction',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # Dataset information

# %%
df.info()       # returns the information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1446 non-null   float64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1440 non-null   object
#  3   Department                1466 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   EducationField            1458 non-null   object
#  6   EmployeeNumber            1470 non-null   int64
#  7   EnvironmentSatisfaction   1470 non-null   int64
#  8   Gender                    1425 non-null   object
#  9   HourlyRate                1470 non-null   int64
#  10  JobInvolvement            1470 non-null   int64
#  11  JobRole                   1460 non-null   object
#  12  JobSatisfaction           1470 non-null   int64
# ...

# %% [markdown]
# # Checking if there are null values in any columns

# %%
df.isnull().sum()       # isnull returns the True/False dataframe
                            #sum: counts the number of True in columns
# Out:
# Age                         24
# Attrition                    0
# BusinessTravel              30
# Department                   4
# DistanceFromHome             0
# EducationField              12
# EmployeeNumber               0
# EnvironmentSatisfaction      0
# Gender                      45
# HourlyRate                   0
# JobInvolvement               0
# JobRole                     10
# JobSatisfaction              0
# MaritalStatus               56
# MonthlyIncome                0
# NumCompaniesWorked           0
# Over18                      54
# OverTime                     0
# PerformanceRating            0
# RelationshipSatisfaction     0
# TotalWorkingYears            0
# TrainingTimesLastYear        0
# WorkLifeBalance              0
# YearsAtCompany               0
# YearsInCurrentRole           0
# YearsSinceLastPromotion      0
# YearsWithCurrManager         0
# dtype: int64

# %% [markdown]
# LEVEL 1 Analysis
# -------------------------
# Identify the type of data in each column (categorical or numerical)?
# 1. Seperate out the categorical columns from the numerical types.
#
# ### Following are the kinds of analysis that can be performed on categorical data:
# 1. Check if the variable is  Nominal or Ordinal.
# 2. Check how many categories are present in a variable.
# 3. Check the Mode of a variable.
# 4. Check for Missing values of a variable.
# 5. Think how the missing values could be treated.
# 6. What kind of graph/chart can be plotted using this data?
#
# Note: We are analyzing only one column at a time (a.k.a. Univariate Analysis)

# %% [markdown]
# # Separating Categorical and Numerical Variables

# %%
# Seprating out the categorical and continuous variables
def seprate_data_types(df):
    categorical = []
    continuous = []
    for column in df.columns:                # looping on the number of columns
        if df[column].nunique() < 43:       # nunique:  returns unique values in the column,
                                                    #here 43 is the hyperparamter and can be changed
            categorical.append(column)
        else:
            continuous.append(column)
            
    return categorical, continuous 


categorical, continuous = seprate_data_types(df)         # Calling the function

# # Tabulate is a package used to print the list, dict or any data sets in a proper format; in table format
from tabulate import tabulate
table = [categorical, continuous]
print(tabulate({"Categorical":categorical,
                "Continuous": continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical               continuous
# ------------------------  --------------
# Attrition                 Age
# BusinessTravel            EmployeeNumber
# Department                HourlyRate
# DistanceFromHome          MonthlyIncome
# EducationField
# EnvironmentSatisfaction
# Gender
# JobInvolvement
# JobRole
# JobSatisfaction
# MaritalStatus
# NumCompaniesWorked
# Over18
# OverTime
# PerformanceRating
# RelationshipSatisfaction
# TotalWorkingYears
# TrainingTimesLastYear
# WorkLifeBalance
# YearsAtCompany
# YearsInCurrentRole
# YearsSinceLastPromotion
# YearsWithCurrManager

# %% [markdown]
# # $$\;\;\;\; Univariate \ Analysis \ of \ Categorical \ Variables$$

# %% [markdown]
# ## Level 1 Analysis

# %% [markdown]
# ### User defined functions for level 1 analysis of categorical columns
# This function will check for the following:
# Unique values
# Mode
# Sum of all the null values
# Total count of missing values

# %%
def info_of_cat(col): 
    print(f"Unique values in {col} are: {df[col].unique()}") # unique: returns the unique values in the col
    print(f"Mode of {col} is {df[col].mode()[0]}")  # mode: returns the mode of the column
    print(f"Number of missing values in {col} is {df[col].isnull().sum()}") # isnull().sum() counts the number of null in dataframe
    if df[col].isnull().sum() > 0:  # check if null values are present
        print(f"\nThere are null values in the {col} column")

# %% [markdown]
# # 1. Analysis of Attrition:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("Attrition") #function returns all the information required for the level 1 analysis
# Out:
# Unique values in Attrition are: ['Yes' 'No']
# Mode of Attrition is No
# Number of missing values in Attrition is 0

# %% [markdown]
# ###### Attrition Flag is a nominal datatype.

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of Attrition")                  # Set the title of the graph
percentage = df["Attrition"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["Attrition"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["Attrition"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## Interpretation: Results show that only 16% of the employees have left the firm while 83.9% are still working with the firm.

# %% [markdown]
# # 2. Analysis of  BusinessTravel:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("BusinessTravel")
# Out:
# Unique values in BusinessTravel are: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel' nan]
# Mode of BusinessTravel is Travel_Rarely
# Number of missing values in BusinessTravel is 30
#
# There are null values in the BusinessTravel column

# %% [markdown]
# #### Business Travel is a nominal datatype.

# %% [markdown]
# Missing value Treatment: Mode of Business Travel
#
# Note: Mode is not the appropriate way to fill the missing value data as this data belongs to the employees of IBM. If the person is traveling frequently and null values are filled with the mode values of those employees who travel rarely, it might lead to the wrong interpretaion.
#
# However, we are replacing the null values with mode for the purpose of demonstration. The appropriate way is to ask the concerned team/individuals for data. In the event of data not being available, we could fill it with zero values.

# %%
bt_mode = df["BusinessTravel"].mode()[0]
print(bt_mode)
df["BusinessTravel"].fillna(bt_mode, inplace = True, axis = 0)
# Out:
# Travel_Rarely

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of Business Travel")              # Set the title of the graph
percentage = df["BusinessTravel"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["BusinessTravel"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["BusinessTravel"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 
plt.show()

# %% [markdown]
# ## Interpretation: Majority of the employees are travelling rarely for business purposes.

# %% [markdown]
# # 3. Analysis of Department:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("Department")
# Out:
# Unique values in Department are: ['Sales' 'Research & Development' 'Human Resources' nan]
# Mode of Department is Research & Development
# Number of missing values in Department is 4
#
# There are null values in the Department column

# %% [markdown]
# #### Department is a nominal datatype.

# %% [markdown]
# ##   Missing value treatment: Mode of the Department
#
# Note: Mode is not a perfect way to way to fill the missing value. In this case, one might need to handle such a situation with caution. This is for demonstration purposes only.

# %%
department_mode = df.Department.mode()[0]
print(department_mode)
df["Department"].fillna(department_mode, inplace = True)
# Out:
# Research & Development

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
data = df["Department"].value_counts()                                  # Value count is an inbuilt function to calculate the number of classes                                                                       #in gender columns
labels =data.keys()                                                  #data keys provide the index names but this function provides the columns 
                                                                     #names if called on dataframe
sns.countplot(x = df["Department"], ax = ax[0])
plt.pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.5) # pctdistance is the distance between the percentage
                                                                     # on pie chart from center.
                                                                     #  explode is to split the slices by the distance provided
                                                                     # autopct: is used to print the number on pie slices.  

plt.show()

# %% [markdown]
# ## Interpretation: 65% of the employees are working in the Research and Development department where 30% are from Sales and only 4% are from HR.

# %% [markdown]
# # 4. Analysis of DistanceFromHome:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("DistanceFromHome") # check for the unique values in the feature
# Out:
# Unique values in DistanceFromHome are: [ 1  8  2  3 24 23 27 16 15 26 19 21  5 11  9  7  6 10  4 25 12 18 29 22
#  14 20 28 17 13]
# Mode of DistanceFromHome is 2
# Number of missing values in DistanceFromHome is 0

# %% [markdown]
# ###### Dependent_count is discrete data (Numerical).
# Our user defined function has mislabeled this column as categorical. We are correcting it below.

# %%
categorical.remove("DistanceFromHome")
continuous.append("DistanceFromHome")

# %% [markdown]
# # 5. Analysis of EducationField:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("EducationField") # check for the unique values in the feature
# Out:
# Unique values in EducationField are: ['Life Sciences' 'Other' 'Medical' 'Marketing' nan 'Technical Degree'
#  'Human Resources']
# Mode of EducationField is Life Sciences
# Number of missing values in EducationField is 12
#
# There are null values in the EducationField column

# %% [markdown]
# ######  EducationField is a nominal datatype (Categorical).

# %% [markdown]
# ##   Missing value treatment: Mode of the EducationField
#
# Note: Mode is not a perfect way to way to fill the missing value. In this case, one might need to handle such a situation with caution. This is for demonstration purposes only.

# %%
ed_mode = df.EducationField.mode()[0]
print(ed_mode)
df["EducationField"].fillna(ed_mode, inplace = True)
# Out:
# Life Sciences

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
data = df["EducationField"].value_counts()                                  # Value count is an inbuilt function to calculate the number of classes                                                                       #in gender columns
labels =data.keys()                                                  #data keys provide the index names but this function provides the columns 
                                                                     #names if called on dataframe
sns.countplot(x = df["EducationField"], ax = ax[0])
plt.pie(x = data, autopct = "%.1f%%", labels = labels, pctdistance = 0.5) # pctdistance is the distance between the percentage
                                                                     # on pie chart from center.
                                                                     #  explode is to split the slices by the distance provided
                                                                     # autopct: is used to print the number on pie slices.  

plt.show()

# %% [markdown]
# ## Interpretation: 73% of the employees are from Medical or Life Science backgrounds.

# %% [markdown]
# # 6. Analysis of EnvironmentSatisfaction:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("EnvironmentSatisfaction") # check for the unique values in the feature
# Out:
# Unique values in EnvironmentSatisfaction are: [2 3 4 1]
# Mode of EnvironmentSatisfaction is 3
# Number of missing values in EnvironmentSatisfaction is 0

# %% [markdown]
# ###### EnvironmentSatisfaction is a ordinal datatype (Categorical) as it is having hierarchy in it.

# %%
fig, ax = plt.subplots(figsize= (10, 7))
ax = sns.countplot(x = df["EnvironmentSatisfaction"])
for bar in ax.patches:                                              # ax.patches returns the rectange object from matplotlib
    percentage = f"{round((bar.get_height() /len(df))*100, 2)}%"          # first it calculate the bar height and then dividing by the number of rows in data(to calculate percentage) 
                                                                    # and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                            # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                            # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )   # va bottom: means percentage would be above the bar head. 
                                                                    # annotate: used to annotate over objects, here objects are the bars
plt.show()

# %% [markdown]
# ## Interpretation: 38% of the employees have lower Environment Satisfaction.
# ---> 1 and 2 are assigned with the lower job satisfaction category.

# %% [markdown]
# # 7. Analysis of Gender:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("Gender")
# Out:
# Unique values in Gender are: ['Female' 'Male' nan]
# Mode of Gender is Male
# Number of missing values in Gender is 45
#
# There are null values in the Gender column

# %% [markdown]
# ###### Gender is a nominal datatype (Categorical).

# %% [markdown]
# # Missing Value Treatment: Gender Column
# Note: One should be careful while filling the gender column. The right approach would be to reach out to the concerned team/individual to collect the data. The best approach would be to leave it blank.

# %%
df["Gender"].fillna("Not Known", inplace = True)

# %%
# Plot the graph-
fig, ax = plt.subplots(figsize= (10, 7))
ax = sns.countplot(x = df["Gender"])
ax.set_xticklabels(ax.get_xticklabels(), rotation = 40 , ha = "right") # set_xticklabels is used to set the labels of the x axis
                                                                       # ax.get_xtickslabels() returns all the labels that we need to print
                                                                       # rotation: rotate the xlabels at angle provided, and
                                                                       # ha: Horizontal axis:-> how you want to keep it. can be changed to center, left, right
count = len(df["Gender"])                                     # counting the number of rows in whole dataset
for bar in ax.patches:                                                 # ax.patches returns the rectange object from matplotlib 
    percentage = f"{round((bar.get_height()/count)*100, 2)} %"           # first it calculate the bar heightand then dividing by the number of row(to calculate percentage)
                                                                            # in data and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                                # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                                # get_height: returns height of rectangle bar.
    ax.annotate(percentage, (x, y), ha = "center", va = "top")          # va: Vertical axis: -> top means percentage would bneath the bar head
                                                                        # annotate: used to annotate over objects. here objects are the bars 
plt.show()

# %% [markdown]
# ## Interpretation: 57% of the employees are males and 39% are females.

# %% [markdown]
# # 8. Analysis of MaritalStatus:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("MaritalStatus")
# Out:
# Unique values in MaritalStatus are: ['Single' 'Married' nan 'Divorced']
# Mode of MaritalStatus is Married
# Number of missing values in MaritalStatus is 56
#
# There are null values in the MaritalStatus column

# %% [markdown]
# ###### Marital_Status is a nominal datatype (Categorical).

# %% [markdown]
# # Missing Value Treatment:
# Note: Mode is not the best approach to fill the missing value for the Marital Status of a person. It is better to leave it blank in this case or reach out to the concerned team/individual to collect the data.

# %%
df["MaritalStatus"].fillna("Not known", inplace = True)

# %% [markdown]
# # Analyzing it again

# %%
print((df["MaritalStatus"].value_counts()/len(df))*100)               #First calculated the number of marital status via value counts inbuilt function and then 
                                                                            #calculated the percentage of it.
fig, ax = plt.subplots(figsize = (10, 4))
sns.countplot(x = df[ 'MaritalStatus'], ax = ax)
for bar in ax.patches:                                                  # ax.patches returns the rectange object from matplotlib
    percentage = f"{round((bar.get_height() /df.shape[0])*100 , 2)} %"  # first it calculate the bar height and then dividing by the number of rows in data and 
                                                                            #multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                                # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                                # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va= "bottom", ha = "center" )       # annotate: used to annotate over objects. here objects are the bars.
plt.show()
# Out:
# Married      44.217687
# Single       30.544218
# Divorced     21.428571
# Not known     3.809524
# Name: MaritalStatus, dtype: float64

# %% [markdown]
# ## Interpretation: 44% of the employees are married and 30% of them are working with Single relationship status.

# %% [markdown]
# # 9. Analysis of Over18:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("Over18")
# Out:
# Unique values in Over18 are: ['Y' nan]
# Mode of Over18 is Y
# Number of missing values in Over18 is 54
#
# There are null values in the Over18 column

# %% [markdown]
# ###### Over18 is a nominal datatype, there is just one category in the over18 column.

# %% [markdown]
# ## Missing Value Treatment: Mode of the Category

# %%
mode = df["Over18"].mode()[0]
df["Over18"].fillna(mode, inplace = True, axis = 0)

# %%
fig, ax = plt.subplots( figsize = (15, 7))
ax.set_title("Count of Over18")                  # Set the title of the graph
percentage = df["Over18"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["Over18"].value_counts().index) # Converting the index of value counts into list

plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## Interpretation: The whole population is above 18 years old. There is no child labor involved.

# %% [markdown]
# # 10. Analysis of  PerformanceRating:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("PerformanceRating")
# Out:
# Unique values in PerformanceRating are: [3 4]
# Mode of PerformanceRating is 3
# Number of missing values in PerformanceRating is 0

# %% [markdown]
# ###### PerformanceRating is a ordinal datatype (Categorical) as it is having hierarchy in it.

# %%
fig, ax = plt.subplots( figsize = (15, 7))
ax.set_title("Count of Performance Rating")                  # Set the title of the graph
percentage = df["PerformanceRating"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["PerformanceRating"].value_counts().index) # Converting the index of value counts into list

plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## Interpretation: Most of the employees are high performers and a very small percentage are average performers.

# %% [markdown]
# # 11. Analysis of  Total Working Years:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("TotalWorkingYears")
# Out:
# Unique values in TotalWorkingYears are: [ 8 10  7  6 12  1 17  5  3 31 13  0 26 24 22  9 19  2 23 14 15  4 29 28
#  21 25 20 11 16 37 38 30 40 18 36 34 32 33 35 27]
# Mode of TotalWorkingYears is 10
# Number of missing values in TotalWorkingYears is 0

# %% [markdown]
# ###### TotalWorkingYears is a Continuous datatype (Numerical).
# This column is mislabeled as categorical by our user defined function. We are correcting it below.

# %%
categorical.remove("TotalWorkingYears")
continuous.append("TotalWorkingYears")

# %% [markdown]
# # 12. Analysis of  Work Life Balance:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %%
info_of_cat("WorkLifeBalance")
# Out:
# Unique values in WorkLifeBalance are: [1 3 2 4]
# Mode of WorkLifeBalance is 3
# Number of missing values in WorkLifeBalance is 0

# %% [markdown]
# ###### Work Life Balance is an ordinal datatype (Categorical) as it is having hierarchy in it.

# %%
fig, ax = plt.subplots( figsize = (15, 7))
ax.set_title("Work Life Balance")                  # Set the title of the graph
percentage = df["WorkLifeBalance"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["WorkLifeBalance"].value_counts().index) # Converting the index of value counts into list

plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## Interpretation: Almost 70% of the employees seem to have a good work life balance.

# %% [markdown]
# # $$\;\;\;\;\;\;Univariate \ Analysis \ of \ Numerical \ Variables$$

# %% [markdown]
# LEVEL 1 Analysis of Numerical Columns
# ----------------------------------------------------------
# Check if the variable is Discrete or Continuous. \
# Measures of central tendency (mean, median) \
# Measure of Dispersion \
# Check for missing values \
# Check for skewness\
# Check for outliers \
# How could the missing values be treated? \
# What kind of graph/chart can be plotted using this data?

# %% [markdown]
# # 13 User defined function for calculating mean, median, standard deviation, and count of all the null values

# %%
def info_of_numerical(col):
    print(f"The mean of the {col} is {df[col].mean()}")
    print(f"The median of the {col} is {df[col].median()}")
    print(f"The mode of the {col} is {df[col].mode()[0]}")
    print(f"The standard deviation of the {col} is {df[col].std()}")
    print(f"Number of missing values in the {col} is {df[col].isnull().sum()}")

# %% [markdown]
# # Names of Continuous Variables

# %%
continuous
# Out:
# ['Age',
#  'EmployeeNumber',
#  'HourlyRate',
#  'MonthlyIncome',
#  'DistanceFromHome',
#  'TotalWorkingYears']

# %% [markdown]
# # 14. Analysis of  the Employee's Age
# LEVEL 1 Analysis of Numerical Data (Univariate Analysis)

# %%
info_of_numerical("Age")
# Out:
# The mean of the Age is 36.93015214384509
# The median of the Age is 36.0
# The mode of the Age is 34.0
# The standard deviation of the Age is 9.16220404447615
# Number of missing values in the Age is 24

# %% [markdown]
# ######  Employee's Age is a continuous datatype (Numerical).

# %%
continuous# Distribution of Customer_Age
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["Age"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["Age"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %% [markdown]
# This is a normal distributed data
# ## Missing value treatment: Mean or Median of the Employee's Age

# %%
mean = 36
df["Age"].fillna(mean, axis = 0, inplace = True)

# %% [markdown]
# # Analyzing it again

# %%
info_of_numerical("Age")
# Out:
# The mean of the Age is 36.914965986394556
# The median of the Age is 36.0
# The mode of the Age is 36.0
# The standard deviation of the Age is 9.087816436803726
# Number of missing values in the Age is 0

# %%
# Distribution of Customer_Age
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["Age"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["Age"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %% [markdown]
# ## Interpretation: Usually employee's age follows a normal distribution. There are no employees above the age of 60.

# %% [markdown]
# # 15. Analysis of  the EmployeeNumber:
# LEVEL 1 Analysis of Numerical Data (Univariate Analysis)

# %%
info_of_numerical("EmployeeNumber")
# Out:
# The mean of the EmployeeNumber is 1024.865306122449
# The median of the EmployeeNumber is 1020.5
# The mode of the EmployeeNumber is 1
# The standard deviation of the EmployeeNumber is 602.024334847475
# Number of missing values in the EmployeeNumber is 0

# %% [markdown]
# ## Interpretation: One is not supposed to perform measures of central tendency on the employee code column of the company.

# %% [markdown]
# # 16. Analysis of  the HourlyRate:
# LEVEL 1 Analysis of Numerical Data (Univariate Analysis)

# %%
info_of_numerical("HourlyRate")
# Out:
# The mean of the HourlyRate is 65.89115646258503
# The median of the HourlyRate is 66.0
# The mode of the HourlyRate is 66
# The standard deviation of the HourlyRate is 20.329427593996158
# Number of missing values in the HourlyRate is 0

# %% [markdown]
# ####  Hourly Rate is a continuous datatype (Numerical).

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["HourlyRate"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["HourlyRate"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %% [markdown]
# ## Interpretation: Majority of the employees have an hourly rate between `$47` to `$83`.

# %% [markdown]
# # 17. Analysis of  the MonthlyIncome:
# LEVEL 1 Analysis of Numerical Data (Univariate Analysis)

# %%
info_of_numerical("MonthlyIncome")
# Out:
# The mean of the MonthlyIncome is 6502.931292517007
# The median of the MonthlyIncome is 4919.0
# The mode of the MonthlyIncome is 2342
# The standard deviation of the MonthlyIncome is 4707.956783097995
# Number of missing values in the MonthlyIncome is 0

# %% [markdown]
# ####  Monthly Income is a continuous datatype (Numerical).

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["MonthlyIncome"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["MonthlyIncome"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %% [markdown]
# This is a right skewed data.
# ## Outliers Analysis and Interpretation:  Majority of the employees are earning below `$8k` per month. There are a few employees who seem to earn more than `$15k` per month.

# %% [markdown]
# ## Further Analysis (Level 3):
# Let's look into the data to check if there is an additional information about the employees who are having lower performance ratings.

# %% [markdown]
# # Students will represent their notebooks, which will be evaluated by the mentor on level 3.

# %% [markdown]
# # 1. Analysis of Business Travel on Attrition

# %% [markdown]
# # One could consider analyzing all the above columns for the employees who are traveling rarely. However it could be a waste of time, hence it is better to consult the domain expert to choose the appropriate columns for further analysis.
# Let's consider the following columns:
# 1. JobRole
# 2. Department
# 3. JobInvolvement
#
# ## Further Analysis (Level 3):
# Based on the employees who are travelling rarely
# 1. Analysis of the JobRole of employees who are attiring.
# 2. Is there any relation between the department and the employees who are churned out and who are still with the bank?
# 3. Do you think Job Involvement could be the factor that is affecting churn?

# %%
#1.1
sns.histplot(df[df['Attrition']=='Yes'],x='Attrition',hue='JobRole',multiple='dodge')
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='Count'>

# %% [markdown]
# There are high numbers of people who quit among the professions Sales Executive,Laboratory Technician, Sales Representative and Research Scientist which Laboratory Technician topping them all.The attrition is lowest for the role of Research Director and relatively low for other roles.

# %%
#1.2
fig,ax=plt.subplots(1,2,figsize=(12,5))
sns.histplot(df,x='Attrition',y='JobRole',cbar=True,ax=ax[0])
sns.histplot(df,x='Attrition',hue='JobRole',multiple='dodge',ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='Count'>

# %% [markdown]
# We can see that there a large number of people who are Sales Representatives quit compared to the number of people working as Sales Representatives.Every other department has a healthy ratio of working people and attrited employees.

# %%
#1.2
fig,ax=plt.subplots(1,2,figsize=(12,5))
sns.histplot(df,x='Attrition',y='JobInvolvement',cbar=True,ax=ax[0])
sns.histplot(df,x='Attrition',hue='JobInvolvement',multiple='dodge',ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='Count'>

# %% [markdown]
# People who are on the higher spectrum of Job Involvement have relatively lesser attrition compared to employees whosen Job Involvement is lower.On the flip side people on the lower end have a strong relation with attrition.

# %% [markdown]
# # 2. Analysis of EducationField with Attrition

# %% [markdown]
# # One could consider analyzing all the above columns for the employees who are from Medical and Life Science backgrounds.  However it could be a waste of time, hence it is better to consult the domain expert to choose the appropriate columns for further analysis.
# Let's consider the following columns:
# 1. Monthly Income
# 2. Years in current role
# 3. Years at company
#
# ## Further Analysis (Level 3):
# Based on the education level (Medical and Life Science)
# 1. Analysis of the JobRole of employees who are from life science and medical backgrounds.
# 2. Is there any relation between the department and the attrition of employees who are from Life Science and Medical education levels?
# 3. Do you think the average hourly rate is different for the employees who are from Life Science or Medical stream?

# %%
#2.1
sns.displot(data=df[(df['EducationField']=='Life Sciences')|(df['EducationField']=='Medical')],x='JobRole',hue='JobRole')
plt.xlabel(rotation=80)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [358], in <cell line: 3>()
#       1 #2.1
#       2 sns.displot(data=df[(df['EducationField']=='Life Sciences')|(df['EducationField']=='Medical')],x='JobRole',hue='JobRole')
# ----> 3 plt.xlabel(rotation=80)
#
# TypeError: xlabel() missing 1 required positional argument: 'xlabel'

# %% [markdown]
# A large chunk of people from medical and life sciences background end up as a research scientist,laboratory technician or as a sales executive with the least chance of ending up in HR.

# %%
#2.2
fig,ax=plt.subplots(1,2,figsize=(12,5))
sns.histplot(df[(df['EducationField']=='Life Sciences')|(df['EducationField']=='Medical')],x='Attrition',y='JobRole',cbar=True,ax=ax[0])
sns.histplot(df[(df['EducationField']=='Life Sciences')|(df['EducationField']=='Medical')],x='Attrition',hue='JobRole',multiple='dodge',ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='Count'>

# %% [markdown]
# A large percentage of people from life sciences and medical educational background quit their job as Human Resources and Sales Representative.The attrition rate for them is low among other Job Roles.

# %%
#2.3
fig,ax=plt.subplots(1,2,figsize=(12,5))
sns.histplot(data=df,x='HourlyRate',ax=ax[0])
ax[0].set_title='All Backgrounds'
sns.histplot(data=df[(df['EducationField']=='Life Sciences')|(df['EducationField']=='Medical')],x='HourlyRate',hue='EducationField',ax=ax[1],multiple='dodge')
ax[1].set_title='Life Sciences and Medical Background'

# %% [markdown]
# We can see that the hourly pay for people in Medical or Life Sciences background is different as the distributions are slightly different from that of the general population.

# %% [markdown]
# # 3. Is there any relation between the Employee's Attrition and the Department?
#
# ### One could consider analyzing all the above columns for the employees who from the sales department. However it could be a waste of time, hence it is better to consult the domain expert to choose the appropriate columns for further analysis.
# Let's consider the following columns:
# 1. Attrition
# 2. Gender
# 3. Hourly Rate
#
# ## Further Analysis (Level 3):
# 1. Analysis of the Employees attrition from the Sales department.
# 2. Do you think gender could be the factor in the attrition of employees from the sales department?
# 3. Is there any relation between the hourly rate of the sales department with respect to the medical department?

# %%
#3.1
sns.histplot(data=df[df['Department']=='Sales'],x='Attrition',hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='Count'>

# %% [markdown]
# There are around 100 employees who quit their jobs in sales deparment compared to 350 people who are now working in it.

# %%
#3.2
fig,ax=plt.subplots(1,2,figsize=(12,5))
sns.histplot(data=df[df['Department']=='Sales'],x='Attrition',hue='Gender',ax=ax[0])
sns.histplot(data=df[df['Department']=='Sales'],x='Attrition',y='Gender',ax=ax[1],cbar=True)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='Gender'>

# %% [markdown]
# There is a larger segment of male population in both employees who quit and are working but they seem to be proportionate with the percenatage of the total.Gender doesn't seem to influence attrition.

# %%
#2.3
t23=df[(df['Department']=='Sales')|(df['Department']=='Research & Development')]
sns.histplot(data=t23,x='HourlyRate',hue='Department')
# Out:
# <AxesSubplot:xlabel='HourlyRate', ylabel='Count'>

# %% [markdown]
# There is a small variation in hourly pay between the people in Sales and Medical

# %% [markdown]
# # 4.  Analysis of Environment Satisfaction with the Attrition
# Level 2 Categorical to Categorical

# %% [markdown]
# # One could consider analyzing all the above columns for the employees who have lower environment satisfaction. However it could be a waste of time, hence it is better to consult the domain expert to choose the appropriate columns for further analysis.
# Let's consider the following columns:
# 1. JobRole
# 2. Department
# 3. HourlyRate
#
# ## Further Analysis (Level 3):
# 1. Analysis of the JobRole of employees who have lower environment satisfaction.
# 2. Is there any relation between the department and attrition of employees who have lower environment satisfaction?
# 3. Do you think the average hourly rate matters in the attrition of employees when they have higher environment satisfaction?

# %%
#4.1
catplot(data=df,x='JobRole',y='EnvironmentSatisfaction',kind='box',size=10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3750: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Everyone other than human resources share a similar outlook on Environment Satisfaction.

# %%
#4.2
sns.catplot(data=df,x='Department',y='EnvironmentSatisfaction',kind='box',hue='Attrition')

# %% [markdown]
# Among the population with low environment satisfaction score there seems to be very less attrition rate in all departments.

# %%
#4.3
sns.catplot(data=df,x='EnvironmentSatisfaction',y='HourlyRate',hue='Attrition',kind='swarm',dodge=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 37.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# People with very high environment satisfaction seem to quit slightly more compared to those with high satifaction when their hourly wages are very low.

# %% [markdown]
# # 5. Gender analysis on Attrition of the employees who left the firm and those who are still with it
# Level 2 Categorical to Categorical

# %% [markdown]
# ### One could consider analyzing all the above columns for the employees who are males and their attrition rate. However it could be a waste of time, hence it is better to consult the domain expert to choose the appropriate columns for further analysis.
# Let's consider the following columns:
# 1. Age
# 2. Department
# 3. HourlyRate
#
# ## Further Analysis (Level 3):
# 1. Analysis of employee's age who are attired.
# 2. Is there any relation between the department and the attrition of the male employees?
# 3. Do you think the average hourly rate matters in attrition of males employees compared to non-attired?

# %%
#5.1
sns.histplot(df[df['Attrition']=='Yes'],x='Age')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# A large section of the population aged around 30 quit thier jobs and fewer people quit on both extremes of age.

# %%
#5.2
sns.histplot(df[df['Gender']=='Male'],x='Department',hue='Attrition',multiple='dodge')
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Count'>

# %% [markdown]
# A proportionate number of male people quit their jobs in every department.

# %%
#5.3
sns.histplot(df[df['Gender']=='Male'],x='HourlyRate',hue='Attrition',multiple='dodge')
# Out:
# <AxesSubplot:xlabel='HourlyRate', ylabel='Count'>

# %% [markdown]
# There seem to be little relation among attrition of male employees with respect to average hourly rate.

# %% [markdown]
# # 6. Marital Status analysis of the employees who have left and who are still with the firm
# Level 2 Categorical to Categorical

# %% [markdown]
# # One could consider analyzing all the above columns for the employees who are single. However it could be a waste of time, hence it is better to consult the domain expert to choose the appropriate columns for further analysis.
# Let's consider the following columns:
# 1. Age
# 2. Monthly Income
# 3. Job Satisfaction
#
# ## Further Analysis (Level 3):
# 1. Analysis of employee's age who are attired and single
# 2. Is there any relation between the monthly income and marital status of employees?
# 3. Do you think job satisfaction could be the factor affecting the attrition of employees who are single?

# %%
#6.1
sns.histplot(df[(df['Attrition']=='Yes')&(df['MaritalStatus']=='Single')],x='Age')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# Most of the single employees who quit are aged between 25 and 35 with a decent portion around 20 as well.The attrition seems to reduce as age increases after 40.

# %%
#6.2
sns.catplot(data=df,x='MaritalStatus',y='MonthlyIncome',kind='swarm')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 32.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 39.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Monthly income seems to be distributed similarly among Single,married and Divorced people on the lower end of salary,whereas on the upper end there are more married people recieving a higher monthly income.

# %%
#6.3
sns.histplot(data=df[df['MaritalStatus']=='Single'],x='JobSatisfaction',hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='Count'>

# %% [markdown]
# There seems to proportionately higher attrition among people with low job satisfaction scores and it decreases with increase in job satisfaction score.

# %% [markdown]
# # 7. Effect of the Performance Rating with the Attrition
# Level 2 Categorical to Categorical

# %% [markdown]
# # One could consider analyzing all the above columns for the employees who are having lower performance ratings.  However it could be a waste of time, hence it is better to consult the domain expert to choose the appropriate columns for further analysis.
# Let's consider the following columns:
# 1. Age
# 2. Years with current manager
# 3. Job Role
#
# ## Further Analysis (Level 3):
# 1. Analysis of employee's age who are having lower performance ratings.
# 2. Is there any relation between the years with the current manager and the lower performance rating?
# 3. Do you think job role could be the factor affecting the performance rating of employees?

# %%
#7.1
sns.displot(data=df,x='Age',hue='PerformanceRating')

# %% [markdown]
# There are a high number of people between 29 and 40 with a low performance rating compared to people whose ages are on the extremes.

# %%
#7.2
sns.displot(data=df,x='YearsWithCurrManager',hue='PerformanceRating')

# %% [markdown]
# Lesser number of people with a lower rating spend a long time with their manager.

# %%
#7.3
sns.catplot(data=df,x='JobRole',y='PerformanceRating',kind='boxen')

# %% [markdown]
# The performance rating of all employees seem to be mostly unaffected by their job role.

# %% [markdown]
# # 8. Job Satisfaction analysis of the employees who have left and who are still with the firm
# Level 2 Categorical to Categorical

# %% [markdown]
# # One could consider analyzing all the above columns for the employees who have lower job satisfaction. However it could be a waste of time, hence it is better to consult the domain expert to choose the appropriate columns for further analysis.
# Let's consider the following columns:
# 1. Job Role
# 2. Department
# 3. HourlyRate
#
# ## Further Analysis (Level 3):
# 1. Analysis of the JobRole of employees who have lower job satisfaction.
# 2. Is there any relation between the department and attrition of employees who have lower job satisfaction?
# 3. Do you think the average hourly rate matters in the attrition of employees when they have lower environment satisfaction?

# %%
#8.1
sns.displot(data=df[df['JobSatisfaction']<=2],x='JobRole',hue='JobSatisfaction',height=10)

# %% [markdown]
# Sales representatives have the highest number of people with low job satisfaction scores ,while human resouces and research director have the lowest.There seems to be a variation in job satisfaction scores by department.

# %%
#8.2
sns.displot(data=df[df['JobSatisfaction']<=2],x='Department',hue='Attrition')

# %% [markdown]
# Among the people with low job satisfaction scores there seem to be a smaller proportion of employees who quit their jobs in Research and Development.

# %%
3#8.3
sns.displot(data=df[df['EnvironmentSatisfaction']<=2],x='HourlyRate',hue='Attrition')

# %% [markdown]
# The average hourly rate follows close to normal distribution among the employees who quit and are who earn between 50 and 80 with a noticable spike at 100.

# %% [markdown]
# # 2nd Step: Categorical to Continuous

# %% [markdown]
# # 1. Employee's Age analysis with their customers who have left and who are still with the firm
# Level 2: Categorical to Continuous

# %% [markdown]
# # One could consider analyzing all the above columns for the employees who are in the age range of 28 to 40 years. However it could be a waste of time, hence it is better to consult the domain expert to choose the appropriate columns for further analysis.
# Let's consider the following columns:
# 1. Job Role
# 2. Monthly Income
# 3. Year at company
#
# ## Further Analysis (Level 3):
# 1. Analysis of the JobRole of employees who have ages between 28 to 40 years.
# 2. Is there any relation between the monthly income and the attrition of the employees who have age between 28 to 40?
# 3. Do you think years at the company could be the factor affecting the attrition of employees?

# %%
sns.displot(data=df[df['Age'].between(28,40)],x='JobRole',y='Age',height=10,cbar=True)
plt.xticks(rotation=45)
sns.displot(data=df[df['Age'].between(28,40)],x='JobRole')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Laboratory Technician'),
#   Text(1, 0, 'Research Scientist'),
#   Text(2, 0, 'Manufacturing Director'),
#   Text(3, 0, 'Healthcare Representative'),
#   Text(4, 0, 'Sales Representative'),
#   Text(5, 0, 'Research Director'),
#   Text(6, 0, 'Manager'),
#   Text(7, 0, 'Sales Executive'),
#   Text(8, 0, 'Human Resources')])

# %% [markdown]
# There are a high number of people aged between 28 and 40 with an unspecified job role,closely followed by Sales Executive and Research Scientist

# %%
#1.2
sns.displot(data=df[df['Age'].between(28,40)],x='MonthlyIncome',hue='Attrition')

# %% [markdown]
# Attrition rate is high among people with less income and it decreases with increase in income.

# %%
#1.3
sns.displot(data=df[df['Age'].between(28,40)],x='YearsAtCompany',hue='Attrition')

# %% [markdown]
# There is high attrition among people who spent less time at the company and it decreases as the years spent in the company increases.

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PerformanceRating', 'RelationshipSatisfaction',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # 2. Is there any relation between the hourly rate of the employees with the employees who have left?
# Level 2: Categorical to Continuous

# %% [markdown]
# # One could consider analyzing all the above columns for the employee's hourly rate who are still working for the firm. However it could be a waste of time, hence it is better to consult the domain expert to choose the appropriate columns for further analysis.
# Let's consider the following columns:
# 1. Age
# 2. Job Role
# 3. Total Working Years
#
# ## Further Analysis (Level 3):
# 1. Analysis of the employees age who are still working with the firm and who have left out.
# 2. Is there any relation between the job role and the hourly rate of the employees who are existing and those who are left out?
# 3. Do you think Total working years is the factor affecting the hourly rate of the employees and resulting in the attrition of the employees?

# %%
#2.1
sns.histplot(df,x='Age',hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# A large proportion of the population who left the company are aged between 25 and 35;a large number of employees aged between 28 and 40 still work at the company.

# %%
#2.2
sns.displot(df,x='HourlyRate',y='JobRole',col='Attrition',cbar=True)

# %% [markdown]
# Sales executives who earn around 50 an hour and research scientists who earn around 75 an hour seem to quit less.

# %%
#2.3
sns.relplot(data=df,x='TotalWorkingYears',y='HourlyRate',hue='Attrition',kind='line')

# %% [markdown]
# There seems to be lesser people who quit late when their hourly rate is low and slightly higher number who quit when  their income is high.People with low experience and low hourly rate and people with high income and high experience seem to quit more.

# %% [markdown]
# # 3. Monthly Income analysis of the employees who have left and who are still with the firm.
# Level 2: Categorical to Continuous

# %% [markdown]
# # One could consider analyzing all the above columns for the employees who are earning less than $6,000. However it could be a waste of time, hence it is better to consult the domain expert to choose the appropriate columns for further analysis.
# Let's consider the following columns:
# 1. Job Role
# 2. Age
# 3. Total working years
#
# ## Further Analysis (Level 3):
# 1. Analysis of the JobRole of employees who are earning less than $6,000.
# 2. Is there any relation between the monthly income and the age of employees who have been left out and who are still working with the firm?
# 3. Do you think Total Working Years could be the factor affecting the monthly income of employees which results in attrition?

# %%
#3.1
sns.displot(data=df[df['MonthlyIncome']<6000],x='JobRole',height=9)

# %% [markdown]
# There are a large number of employees in Sales Executive, Research Scientist, Laboratory Technician who earn less than $6000.

# %%
#3.2
sns.relplot(data=df[df['Attrition']=='Yes'],x='MonthlyIncome',y='Age',kind='line')
sns.relplot(data=df[df['Attrition']=='No'],x='MonthlyIncome',y='Age',kind='line')
sns.relplot(data=df,x='MonthlyIncome',y='Age',col='Attrition')

# %% [markdown]
# There are a larger number of people who quit in various age groups with high incomes.

# %%
#3.3
sns.relplot(data=df,x='TotalWorkingYears',y='MonthlyIncome',hue='Attrition')
sns.relplot(data=df,x='TotalWorkingYears',y='MonthlyIncome',hue='Attrition',kind='line')

# %% [markdown]
# People with the highest income seemed to quit irrespective of their age,a lot of people with monthly income of $10000 quit in all age groups.

# %% [markdown]
# # 4. How distance from home is impacting the attrition of employees?
# Level 2: Categorical to Continuous

# %% [markdown]
# # One could consider analyzing all the above columns for the employees who have a distance larger than 7 km. However, it could be a waste of time, hence it is better to consult the domain expert to choose the appropriate columns for further analysis.
# Let's consider the following columns:
# 1. Job role
# 2. Monthly Income
# 3. Job Involvement
#
# ## Further Analysis (Level 3):
# 1. Analysis of the JobRole of employees who have a distance larger than 7 km.
# 2. Is there any relation between the monthly income and the attrition of the employees who have a distance larger than 7 km?
# 3. Do you think job involvement could be the factor affecting the attrition of employees who have a distance larger than 7 km?

# %%
#4.1
sns.histplot(df[df['DistanceFromHome']>7],x='JobRole')
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='Count'>

# %% [markdown]
# There are a large number of Sales Executives,Sales Representatives and Research scientists who travel kmore than 7 km everyday.

# %%
#4.2
sns.histplot(df[df['DistanceFromHome']>7],x='MonthlyIncome',hue='Attrition')
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Count'>

# %% [markdown]
# People who earn between 2000 and 5000 quit their job the most.

# %%
#4.3
sns.histplot(df[df['DistanceFromHome']>7],x='JobInvolvement',hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='Count'>

# %% [markdown]
# People with less job involvement quit their jobs the most.

# %% [markdown]
# # 5. Is there any relation between the total working years of the employees with attrition?
# Level 2: Categorical to Continuous

# %% [markdown]
# # One could consider analyzing all the above columns for the employees who are having higher working experience. However it could be a waste of time, hence it is better to consult the domain expert to choose the appropriate columns for further analysis.
# Let's consider the following columns:
# 1. Job Role
# 2. Monthly Income
# 3. Age
#
# ## Further Analysis (Level 3):
# 1. Analysis of the JobRole of employees who have higher working experience.
# 2. Is there any relation between the monthly income and the attrition of the employees who have higher working experience (greater than 10)?
# 3. Do you think years at the company could be the factor affecting the attrition of employees?

# %%
#5.1
sns.histplot(df[df['TotalWorkingYears']>=10],x='JobRole')
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='Count'>

# %% [markdown]
# There are an almost equal number of employees who have more than 10 years of experience as Sales Executive, Research Scientist, Laboratory Technician,
#  Manufacturing Director, Healthcare Representative,a very few number of Healthcare Representative and a large number of Research Directors.

# %%
#5.2
sns.histplot(df[df['TotalWorkingYears']>=10],x='MonthlyIncome',hue='Attrition')
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Count'>

# %% [markdown]
# There is a relatively high attrition among people who earn around 2500 amonth and it gardually decreases till 10000 where there's a sudden spike.

# %%
#5.3
sns.histplot(df,x='YearsAtCompany',hue='Attrition')
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='Count'>

# %% [markdown]
# There is a relatively high attrition among people spent no years at the company and it gardually decreases till 10 where there's a sudden spike,a very low among people who spent more than 20 years at the company.
